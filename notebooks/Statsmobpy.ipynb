# %%
import sys
# !{sys.executable} -m pip install statsbombpy
# Out:
# ...
#      |████████████████████████████████| 58 kB 5.5 MB/s eta 0:00:011
# ...
#   Using cached url_normalize-1.4.3-py2.py3-none-any.whl (6.8 kB)
# ...
#   Using cached cattrs-22.2.0-py3-none-any.whl (35 kB)
# ...

# %%
from statsbombpy import sb

# %%
sb.competitions()
# Out:
# /Users/sayedsohail/opt/anaconda3/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 1               16          1                    Europe
# 2               16          2                    Europe
# 3               16         27                    Europe
# 4               16         26                    Europe
# 5               16         25                    Europe
# 6               16         24                    Europe
# 7               16         23                    Europe
# 8               16         22                    Europe
# 9               16         21                    Europe
# 10              16         41                    Europe
# 11              16         39                    Europe
# 12              16         37                    Europe
# ...

# %%
sb.competitions().drop_duplicates(['country_name', 'competition_name'])
# Out:
# /Users/sayedsohail/opt/anaconda3/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#     competition_id  season_id              country_name  \
# 0               16          4                    Europe
# 15              37         90                   England
# 18              43        106             International
# 20            1238        108                     India
# 21              11         90                     Spain
# 38              49          3  United States of America
# 39               2         44                   England
# 40              55         43                    Europe
# 41              53        106                    Europe
# 42              72         30             International
#
#            competition_name competition_gender  competition_youth  \
# 0          Champions League               male              False
# ...

# %%
df_2022 = sb.matches(competition_id=43, season_id=106)
df_2022.head(5)
# Out:
# /Users/sayedsohail/opt/anaconda3/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off                     competition season  \
# 0   3857258  2022-11-24  21:00:00.000  International - FIFA World Cup   2022
# 1   3857288  2022-11-26  12:00:00.000  International - FIFA World Cup   2022
# 2   3857267  2022-11-29  17:00:00.000  International - FIFA World Cup   2022
# 3   3869321  2022-12-09  21:00:00.000  International - FIFA World Cup   2022
# 4   3857287  2022-11-24  15:00:00.000  International - FIFA World Cup   2022
#
#      home_team    away_team  home_score  away_score match_status  ...  \
# 0       Brazil       Serbia           2           0    available  ...
# 1      Tunisia    Australia           0           1    available  ...
# 2      Ecuador      Senegal           1           2    available  ...
# ...

# %%
df_2022.columns.tolist()
# Out:
# ['match_id',
#  'match_date',
#  'kick_off',
#  'competition',
#  'season',
#  'home_team',
#  'away_team',
#  'home_score',
#  'away_score',
#  'match_status',
#  'match_status_360',
#  'last_updated',
#  'last_updated_360',
#  'match_week',
#  'competition_stage',
#  'stadium',
#  'referee',
#  'home_managers',
#  'away_managers',
#  'data_version',
#  'shot_fidelity_version',
#  'xy_fidelity_version']

# %%
df_2018 = sb.matches(competition_id=43, season_id=3)
df_2018.head(5)
# Out:
# /Users/sayedsohail/opt/anaconda3/lib/python3.9/site-packages/statsbombpy/api_client.py:21: NoAuthWarning: credentials were not supplied. open data access only
#   warnings.warn(
#    match_id  match_date      kick_off                     competition season  \
# 0      7548  2018-06-22  14:00:00.000  International - FIFA World Cup   2018
# 1      7578  2018-06-15  14:00:00.000  International - FIFA World Cup   2018
# 2      7553  2018-06-23  17:00:00.000  International - FIFA World Cup   2018
# 3      7544  2018-06-20  17:00:00.000  International - FIFA World Cup   2018
# 4      7536  2018-06-18  17:00:00.000  International - FIFA World Cup   2018
#
#      home_team     away_team  home_score  away_score match_status  ...  \
# 0       Brazil    Costa Rica           2           0    available  ...
# 1        Egypt       Uruguay           0           1    available  ...
# 2  South Korea        Mexico           1           2    available  ...
# ...
