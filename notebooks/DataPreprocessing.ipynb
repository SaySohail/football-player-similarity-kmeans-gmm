# %%
# Python ≥3.5 (ideally)
import platform
import sys, getopt
assert sys.version_info >= (3, 5)
import csv

# !{sys.executable} -m pip install html5lib
# Import Dependencies
# %matplotlib inline

# Math Operations
import numpy as np
from math import pi

# Datetime
import datetime
from datetime import date
import time

# Data Preprocessing
import pandas as pd
import ydata_profiling as pp
import os
import re
import random
import glob
from io import BytesIO
from pathlib import Path

# Reading directories
import glob
import os

# Working with JSON
import json
from pandas.io.json import json_normalize

# Web Scraping
import requests
from bs4 import BeautifulSoup
import re


# Machine Learning
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture as GMM
from sklearn.metrics import silhouette_score,silhouette_samples
from sklearn.metrics import davies_bouldin_score,calinski_harabasz_score

# Data Visualisation
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import seaborn as sns
plt.style.use('seaborn-whitegrid')
import missingno as msno

# Progress Bar
from tqdm import tqdm

# Display in Jupyter
from IPython.display import Image, YouTubeVideo
from IPython.core.display import HTML

# Ignore Warnings
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")


from soccerplots.radar_chart import Radar   # for custom radar visuals
print('Setup Complete')
# Out:
# ...
# Setup Complete

# %%
events = pd.read_csv('/Users/sayedsohail/Downloads/archive/df_full_premierleague.csv')

# %%
events.head(10)
# Out:
#    id                                link_match  season      date  \
# 0   0  https://www.premierleague.com/match/7186  10-Nov  01/11/10
# 1   1  https://www.premierleague.com/match/7404  10-Nov  11/04/11
# 2   2  https://www.premierleague.com/match/7255  10-Nov  13/12/10
# 3   3  https://www.premierleague.com/match/7126  10-Nov  13/09/10
# 4   4  https://www.premierleague.com/match/7350  10-Nov  14/02/11
# 5   5  https://www.premierleague.com/match/7096  10-Nov  16/08/10
# 6   6  https://www.premierleague.com/match/7166  10-Nov  18/10/10
# 7   7  https://www.premierleague.com/match/7258  10-Nov  20/12/10
# 8   8  https://www.premierleague.com/match/7226  10-Nov  22/11/10
# 9   9  https://www.premierleague.com/match/7106  10-Nov  23/08/10
#
#            home_team             away_team result_full result_ht  \
# 0          Blackpool  West Bromwich Albion      02-Jan       1-0
# 1          Liverpool       Manchester City         3-0       3-0
# ...

# %%
events.columns.tolist()
# Out:
# ['id',
#  'link_match',
#  'season',
#  'date',
#  'home_team',
#  'away_team',
#  'result_full',
#  'result_ht',
#  'home_clearances',
#  'home_corners',
#  'home_fouls_conceded',
#  'home_offsides',
#  'home_passes',
#  'home_possession',
#  'home_red_cards',
#  'home_shots',
#  'home_shots_on_target',
#  'home_tackles',
#  'home_touches',
#  'home_yellow_cards',
#  'away_clearances',
#  'away_corners',
#  'away_fouls_conceded',
#  'away_offsides',
#  'away_passes',
#  'away_possession',
#  'away_red_cards',
#  'away_shots',
#  'away_shots_on_target',
#  'away_tackles',
#  'away_touches',
#  'away_yellow_cards',
#  'goal_home_ft',
#  'goal_away_ft',
#  'sg_match_ft',
#  'goal_home_ht',
#  'goal_away_ht',
#  'sg_match_ht',
#  'clearances_avg_H',
#  'corners_avg_H',
#  'fouls_conceded_avg_H',
#  'offsides_avg_H',
#  'passes_avg_H',
#  'possession_avg_H',
#  'red_cards_avg_H',
#  'shots_avg_H',
#  'shots_on_target_avg_H',
#  'tackles_avg_H',
#  'touches_avg_H',
# ...

# %%
final_data = events[['id',
 'link_match',
 'season',
 'date',
 'home_team',
 'away_team',
 'result_full',
 'result_ht',
 'home_clearances',
 'home_corners',
 'home_fouls_conceded',
 'home_offsides',
 'home_passes',
 'home_possession',
 'home_red_cards',
 'home_shots',
 'home_shots_on_target',
 'home_tackles',
 'home_touches',
 'home_yellow_cards',
 'away_clearances',
 'away_corners',
 'away_fouls_conceded',
 'away_offsides',
 'away_passes',
 'away_possession',
 'away_red_cards',
 'away_shots',
 'away_shots_on_target',
 'away_tackles',
 'away_touches',
 'away_yellow_cards',
 'goal_home_ft',
 'goal_away_ft',]]

# %%
final_data.columns.tolist()
# Out:
# ['id',
#  'link_match',
#  'season',
#  'date',
#  'home_team',
#  'away_team',
#  'result_full',
#  'result_ht',
#  'home_clearances',
#  'home_corners',
#  'home_fouls_conceded',
#  'home_offsides',
#  'home_passes',
#  'home_possession',
#  'home_red_cards',
#  'home_shots',
#  'home_shots_on_target',
#  'home_tackles',
#  'home_touches',
#  'home_yellow_cards',
#  'away_clearances',
#  'away_corners',
#  'away_fouls_conceded',
#  'away_offsides',
#  'away_passes',
#  'away_possession',
#  'away_red_cards',
#  'away_shots',
#  'away_shots_on_target',
#  'away_tackles',
#  'away_touches',
#  'away_yellow_cards',
#  'goal_home_ft',
#  'goal_away_ft']

# %%
final_data = final_data.drop('link_match',axis=1)

# %%
final_data = final_data.drop('season',axis=1)

# %%
final_data = final_data.drop('date',axis=1)

# %%
final_data = final_data.drop('home_team',axis=1)

# %%
final_data = final_data.drop('away_team',axis=1)

# %%
final_data = final_data.drop('result_full',axis=1)

# %%
final_data = final_data.drop('result_ht',axis=1)

# %%
final_data.columns.tolist()
# Out:
# ['id',
#  'home_clearances',
#  'home_corners',
#  'home_fouls_conceded',
#  'home_offsides',
#  'home_passes',
#  'home_possession',
#  'home_red_cards',
#  'home_shots',
#  'home_shots_on_target',
#  'home_tackles',
#  'home_touches',
#  'home_yellow_cards',
#  'away_clearances',
#  'away_corners',
#  'away_fouls_conceded',
#  'away_offsides',
#  'away_passes',
#  'away_possession',
#  'away_red_cards',
#  'away_shots',
#  'away_shots_on_target',
#  'away_tackles',
#  'away_touches',
#  'away_yellow_cards',
#  'goal_home_ft',
#  'goal_away_ft']

# %%
final_data['result'] = ''

# %%
final_data.loc[final_data['goal_home_ft'] > final_data['goal_away_ft'], 'result'] = 'home_win'
final_data.loc[final_data['goal_home_ft'] < final_data['goal_away_ft'], 'result'] = 'away_win'
final_data.loc[final_data['goal_home_ft'] == final_data['goal_away_ft'], 'result'] = 'draw'

# %%
final_data.columns.tolist()
# Out:
# ['id',
#  'home_clearances',
#  'home_corners',
#  'home_fouls_conceded',
#  'home_offsides',
#  'home_passes',
#  'home_possession',
#  'home_red_cards',
#  'home_shots',
#  'home_shots_on_target',
#  'home_tackles',
#  'home_touches',
#  'home_yellow_cards',
#  'away_clearances',
#  'away_corners',
#  'away_fouls_conceded',
#  'away_offsides',
#  'away_passes',
#  'away_possession',
#  'away_red_cards',
#  'away_shots',
#  'away_shots_on_target',
#  'away_tackles',
#  'away_touches',
#  'away_yellow_cards',
#  'goal_home_ft',
#  'goal_away_ft',
#  'result']

# %%
final_data['away_corners'].describe()
# Out:
# count    4070.000000
# mean        4.747420
# std         2.740086
# min         0.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max        19.000000
# Name: away_corners, dtype: float64

# %%
final_data.head(10)
# Out:
#    id  home_clearances  home_corners  home_fouls_conceded  home_offsides  \
# 0   0               15             8                   16              2
# 1   1               16             6                    6              5
# 2   2               26             5                    9              3
# 3   3               26             8                   12              2
# 4   4               50             4                   11              1
# 5   5               15             5                    9              4
# 6   6               30             5                   12              6
# 7   7                9            10                   10              2
# 8   8               44             4                    6              2
# 9   9               24             5                   13              1
#
#    home_passes  home_possession  home_red_cards  home_shots  \
# 0          550             65.4               0          26
# ...

# %%
final_data.describe()
# Out:
#                 id  home_clearances  home_corners  home_fouls_conceded  \
# count  4070.000000      4070.000000   4070.000000          4070.000000
# mean   2034.500000        24.721622      5.945700            10.778624
# std    1175.052127        11.240546      3.136957             3.434517
# min       0.000000         0.000000      0.000000             0.000000
# 25%    1017.250000        17.000000      4.000000             8.000000
# 50%    2034.500000        23.000000      6.000000            11.000000
# 75%    3051.750000        31.000000      8.000000            13.000000
# max    4069.000000        73.000000     19.000000            24.000000
#
#        home_offsides  home_passes  home_possession  home_red_cards  \
# count    4070.000000  4070.000000      4070.000000     4070.000000
# mean        2.126044   450.428993        51.230393        0.059705
# std         1.681169   125.676926        11.529756        0.244121
# ...

# %%
cat_df = pd.DataFrame()
cat_df = pd.DataFrame({'result': final_data['result']})

# %%
cat_df['home_clearances'] = pd.cut(final_data['home_clearances'],
                            bins=[-1,0, 25, 50, 75, 100],
                            labels=['<0','0to25', '25to50', '50to75', '75to100'])

# %%
cat_df.head(10)
# Out:
#      result home_clearances
# 0  home_win           0to25
# 1  home_win           0to25
# 2  home_win          25to50
# 3  home_win          25to50
# 4      draw          25to50
# 5  home_win           0to25
# 6      draw          25to50
# 7  away_win           0to25
# 8      draw          25to50
# 9  home_win           0to25

# %%
cat_df['home_corners'] = pd.cut(final_data['home_corners'],
                            bins=[-1,0, 5, 10, 15, 20,25],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25'])

# %%
cat_df['home_fouls_conceded'] = pd.cut(final_data['home_fouls_conceded'],
                            bins=[-1,0, 5, 10, 15, 20,25],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25'])

# %%
cat_df['home_offsides'] = pd.cut(final_data['home_offsides'],
                            bins=[-1,0, 2, 4, 6, 8,10,12,14],
                            labels=['<0','0to2', '2to4', '4to6', '6to8', '8to10', '10to12', '12to14'])

# %%
cat_df['home_passes'] = pd.cut(final_data['home_passes'],
                            bins=[-1,0, 200, 400, 600, 800,1000,1200,1400],
                            labels=['<0','0to200', '200to400', '400to600', '600to800', '800to1000', '1000to1200', '1200to1400'])

# %%
cat_df['home_possession'] = pd.cut(final_data['home_possession'],
                            bins=[-1,0, 20, 40, 60, 80,100],
                            labels=['<0','0to20', '20to40', '40to60', '60to80', '80to100'])

# %%
cat_df['home_red_cards'] = pd.cut(final_data['home_red_cards'],
                                  bins=[-1,0, 1, 2, 3, 4, 5, 6],
                                  labels=['<0','0to1', '1to2', '2to3', '3to4', '4to5', '5to6'])

# %%
cat_df['home_shots'] = pd.cut(final_data['home_shots'],
                             bins=[-1,0, 5, 10, 15, 20,25, 30, 35, 40, 45, 50],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25', '25to30', '30to35', '35to40', '40to45', '45to50'])

# %%
cat_df['home_shots_on_target'] = pd.cut(final_data['home_shots_on_target'],
                             bins=[-1,0, 5, 10, 15, 20,25, 30, 35, 40, 45, 50],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25', '25to30', '30to35', '35to40', '40to45', '45to50'])

# %%
cat_df['home_tackles'] = pd.cut(final_data['home_tackles'],
                             bins=[-1,0, 5, 10, 15, 20,25, 30, 35, 40, 45, 50],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25', '25to30', '30to35', '35to40', '40to45', '45to50'])

# %%
cat_df['home_touches'] = pd.cut(final_data['home_touches'],
                            bins=[-1,0, 200, 400, 600, 800,1000,1200,1400],
                            labels=['<0','0to200', '200to400', '400to600', '600to800', '800to1000', '1000to1200', '1200to1400'])

# %%
cat_df['home_yellow_cards'] = pd.cut(final_data['home_yellow_cards'],
                                  bins=[-1,0, 1, 2, 3, 4, 5, 6, 7, 8, ],
                                  labels=['<0','0to1', '1to2', '2to3', '3to4', '4to5', '5to6', '6to7', '7to8'])

# %%
cat_df['away_clearances'] = pd.cut(final_data['away_clearances'],
                            bins=[-1,0, 25, 50, 75, 100],
                            labels=['<0','0to25', '25to50', '50to75', '75to100'])

# %%
cat_df['away_corners'] = pd.cut(final_data['away_corners'],
                            bins=[-1,0, 5, 10, 15, 20,25],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25'])

# %%
cat_df['away_fouls_conceded'] = pd.cut(final_data['away_fouls_conceded'],
                            bins=[-1,0, 5, 10, 15, 20,25],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25'])

# %%
cat_df['away_offsides'] = pd.cut(final_data['away_offsides'],
                            bins=[-1,0, 2, 4, 6, 8,10,12,14],
                            labels=['<0','0to2', '2to4', '4to6', '6to8', '8to10', '10to12', '12to14'])

# %%
cat_df['away_passes'] = pd.cut(final_data['away_passes'],
                            bins=[-1,0, 200, 400, 600, 800,1000,1200,1400],
                            labels=['<0','0to200', '200to400', '400to600', '600to800', '800to1000', '1000to1200', '1200to1400'])

# %%
cat_df['away_possession'] = pd.cut(final_data['away_possession'],
                            bins=[-1,0, 20, 40, 60, 80,100],
                            labels=['<0','0to20', '20to40', '40to60', '60to80', '80to100'])

# %%
cat_df['away_red_cards'] = pd.cut(final_data['away_red_cards'],
                                  bins=[-1,0, 1, 2, 3, 4, 5, 6],
                                  labels=['<0','0to1', '1to2', '2to3', '3to4', '4to5', '5to6'])

# %%
cat_df['away_shots'] = pd.cut(final_data['away_shots'],
                             bins=[-1,0, 5, 10, 15, 20,25, 30, 35, 40, 45, 50],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25', '25to30', '30to35', '35to40', '40to45', '45to50'])

# %%
cat_df['away_shots_on_target'] = pd.cut(final_data['away_shots_on_target'],
                             bins=[-1,0, 5, 10, 15, 20,25, 30, 35, 40, 45, 50],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25', '25to30', '30to35', '35to40', '40to45', '45to50'])

# %%
cat_df['away_tackles'] = pd.cut(final_data['away_tackles'],
                             bins=[-1,0, 5, 10, 15, 20,25, 30, 35, 40, 45, 50],
                            labels=['<0','0to5', '5to10', '10to15', '15to20', '20to25', '25to30', '30to35', '35to40', '40to45', '45to50'])

# %%
cat_df['away_touches'] = pd.cut(final_data['away_touches'],
                            bins=[-1,0, 200, 400, 600, 800,1000,1200,1400],
                            labels=['<0','0to200', '200to400', '400to600', '600to800', '800to1000', '1000to1200', '1200to1400'])

# %%
cat_df['away_yellow_cards'] = pd.cut(final_data['away_yellow_cards'],
                                  bins=[-1,0, 1, 2, 3, 4, 5, 6, 7, 8, ],
                                  labels=['<0','0to1', '1to2', '2to3', '3to4', '4to5', '5to6', '6to7', '7to8'])

# %%
cat_df.head(10)
# Out:
#      result home_clearances home_corners home_fouls_conceded home_offsides  \
# 0  home_win           0to25        5to10              15to20          0to2
# 1  home_win           0to25        5to10               5to10          4to6
# 2  home_win          25to50         0to5               5to10          2to4
# 3  home_win          25to50        5to10              10to15          0to2
# 4      draw          25to50         0to5              10to15          0to2
# 5  home_win           0to25         0to5               5to10          2to4
# 6      draw          25to50         0to5              10to15          4to6
# 7  away_win           0to25        5to10               5to10          0to2
# 8      draw          25to50         0to5               5to10          0to2
# 9  home_win           0to25         0to5              10to15          0to2
#
#   home_passes home_possession home_red_cards home_shots home_shots_on_target  \
# ...

# %%
final_data.head(10)
# Out:
#    id  home_clearances  home_corners  home_fouls_conceded  home_offsides  \
# 0   0               15             8                   16              2
# 1   1               16             6                    6              5
# 2   2               26             5                    9              3
# 3   3               26             8                   12              2
# 4   4               50             4                   11              1
# 5   5               15             5                    9              4
# 6   6               30             5                   12              6
# 7   7                9            10                   10              2
# 8   8               44             4                    6              2
# 9   9               24             5                   13              1
#
#    home_passes  home_possession  home_red_cards  home_shots  \
# 0          550             65.4               0          26
# ...

# %%
cat_df['goals_home'] = final_data['goal_home_ft']

# %%
cat_df['goals_away'] = final_data['goal_away_ft']

# %%
cat_df.head(10)
# Out:
#      result home_clearances home_corners home_fouls_conceded home_offsides  \
# 0  home_win           0to25        5to10              15to20          0to2
# 1  home_win           0to25        5to10               5to10          4to6
# 2  home_win          25to50         0to5               5to10          2to4
# 3  home_win          25to50        5to10              10to15          0to2
# 4      draw          25to50         0to5              10to15          0to2
# 5  home_win           0to25         0to5               5to10          2to4
# 6      draw          25to50         0to5              10to15          4to6
# 7  away_win           0to25        5to10               5to10          0to2
# 8      draw          25to50         0to5               5to10          0to2
# 9  home_win           0to25         0to5              10to15          0to2
#
#   home_passes home_possession home_red_cards home_shots home_shots_on_target  \
# ...

# %%
# creating final dataframe to be used for models
cat_df.to_csv('cat_df.csv', index = False)
cat_df1 = pd.read_csv("cat_df.csv")

# %%
cat_df1.head(10)
# Out:
#      result home_clearances home_corners home_fouls_conceded home_offsides  \
# 0  home_win           0to25        5to10              15to20          0to2
# 1  home_win           0to25        5to10               5to10          4to6
# 2  home_win          25to50         0to5               5to10          2to4
# 3  home_win          25to50        5to10              10to15          0to2
# 4      draw          25to50         0to5              10to15          0to2
# 5  home_win           0to25         0to5               5to10          2to4
# 6      draw          25to50         0to5              10to15          4to6
# 7  away_win           0to25        5to10               5to10          0to2
# 8      draw          25to50         0to5               5to10          0to2
# 9  home_win           0to25         0to5              10to15          0to2
#
#   home_passes home_possession home_red_cards home_shots home_shots_on_target  \
# ...

# %%
cat_df1.columns.tolist()
# Out:
# ['result',
#  'home_clearances',
#  'home_corners',
#  'home_fouls_conceded',
#  'home_offsides',
#  'home_passes',
#  'home_possession',
#  'home_red_cards',
#  'home_shots',
#  'home_shots_on_target',
#  'home_tackles',
#  'home_touches',
#  'home_yellow_cards',
#  'away_clearances',
#  'away_corners',
#  'away_fouls_conceded',
#  'away_offsides',
#  'away_passes',
#  'away_possession',
#  'away_red_cards',
#  'away_shots',
#  'away_shots_on_target',
#  'away_tackles',
#  'away_touches',
#  'away_yellow_cards',
#  'goals_home',
#  'goals_away']

# %%
# Counts of missing values
null_value_stats = cat_df.isnull().sum(axis=0)
null_value_stats[null_value_stats != 0]
# Out:
# away_fouls_conceded    2
# away_yellow_cards      1
# dtype: int64

# %%
cat_df.head(10)
# Out:
#      result home_clearances home_corners home_fouls_conceded home_offsides  \
# 0  home_win           0to25        5to10              15to20          0to2
# 1  home_win           0to25        5to10               5to10          4to6
# 2  home_win          25to50         0to5               5to10          2to4
# 3  home_win          25to50        5to10              10to15          0to2
# 4      draw          25to50         0to5              10to15          0to2
# 5  home_win           0to25         0to5               5to10          2to4
# 6      draw          25to50         0to5              10to15          4to6
# 7  away_win           0to25        5to10               5to10          0to2
# 8      draw          25to50         0to5               5to10          0to2
# 9  home_win           0to25         0to5              10to15          0to2
#
#   home_passes home_possession home_red_cards home_shots home_shots_on_target  \
# ...
